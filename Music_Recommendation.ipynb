# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
df= pd.read_csv("spotify_millsongdata.csv")

# %%
df.head(5)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
# 3   ABBA                   Bang                  /a/abba/bang_20598415.html
# 4   ABBA       Bang-A-Boomerang      /a/abba/bang+a+boomerang_20002668.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \r\nA...
# 1  Take it easy with me, please  \r\nTouch me gen...
# 2  I'll never know why I had to go  \r\nWhy I had...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# link      0
# text      0
# dtype: int64

# %%
df= df.sample(5000).drop('link', axis=1).reset_index(drop=True)

# %%
df.head(10)
# Out:
#               artist                  song  \
# 0  Dusty Springfield   No Sad Songs For Me
# 1       Bonnie Raitt         Walking Blues
# 2        Whiskeytown           Turn Around
# 3          Nightwish  Last Ride Of The Day
# 4   Michael W. Smith        I Miss The Way
# 5           Lou Reed        Style It Takes
# 6     Marilyn Manson            Every Time
# 7    Beautiful South         Property Quiz
# 8                Sia           Bring Night
# 9     Linda Ronstadt        Love Is A Rose
#
#                                                 text
# 0  (Tom Springfield)  \r\n  \r\nThe Springfields ...
# 1  I woke up this mornin'  \r\nFeelin' round for ...
# 2  Want to cross but I don't think I can  \r\nIt'...
# 3  We live in every moment but this one  \r\nWhy ...
# 4  Once a true believer  \r\nOnce there was a fir...
# 5  You've got the money, I've got the time  \r\nY...
# 6  Speak to the sinners  \r\nIs it a crime for  \...
# 7  Little seas can be big seas  \r\nTo the wrong ...
# 8  Bring night, bring the night on  \r\nBring a l...
# 9  Love is a rose but you better not pick it  \r\...

# %%
df['text'][0]
# Out:
# "(Tom Springfield)  \r\n  \r\nThe Springfields  \r\n  \r\nNo sad songs for me  \r\nSoon our love will be  \r\nJust a memory  \r\nIt's all over  \r\n  \r\nI walk around imagining  \r\nThe way you'll say goodbye  \r\nAnd when you try to tell me  \r\nI just hope that I won't cry  \r\n  \r\nNo sad songs for me  \r\nSoon our love will be  \r\nJust a memory  \r\nIt's all over  \r\n  \r\nThe glow has gone forever  \r\nAnd our dreams have turned to dust  \r\nI don't know how I can go on  \r\nAnd yet I know I must  \r\n  \r\nNo sad songs for me  \r\nSoon our love will be  \r\nJust a memory  \r\nIt's all over  \r\n  \r\nIt breaks my heart to feel this way  \r\nAlthough I try to smile  \r\nTo think I'll be alone again  \r\nIn just a little while  \r\n  \r\nNo sad songs for me  \r\nSoon our love will be  \r\nJust a memory  \r\nIt's all over  \r\nIt's all over  \r\nIt's all over\r\n\r\n"

# %%
df.shape
# Out:
# (5000, 3)

# %%
df['text'] = df['text'].str.lower().replace(r'^\w\s', ' ').replace(r'\n', ' ', regex = True)

# %%
df.tail(5)
# Out:
#                artist                      song  \
# 4995    Aiza Seguerra         In My Life Medley
# 4996        Metallica        Here Comes Revenge
# 4997       Don Henley                Shangri-La
# 4998  Alice In Chains                     Again
# 4999    Black Sabbath  Kill In The Spirit World
#
#                                                    text
# 4995  there are places i remember  \r all my life  \...
# 4996  little grave i'm grieving, i will mend you  \r...
# 4997  every day's a new day  \r that's what i've bee...
# 4998  hey, let them do it again, yeah  \r hey, you s...
# 4999  there's something wrong, there's a chill in th...

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk

# %%
nltk.download("punkt")         # Tokenizer
nltk.download("wordnet")       # WordNet lexical database
nltk.download("stopwords")     # Common stop words
nltk.download("averaged_perceptron_tagger")  # POS tagging
nltk.download("omw-1.4")       # WordNet multilingual data
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import nltk
from nltk.stem.porter import PorterStemmer

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
stemmer = PorterStemmer()

# %%
def token(txt):
    token = nltk.word_tokenize(txt)
    a =[stemmer.stem(w) for w in token]
    return " ".join(a)

# %%
token("you are beautiful")
# Out:
# 'you are beauti'

# %%
df['text'].apply(lambda x: token(x))
# Out:
# 0       ( tom springfield ) the springfield no sad son...
# 1       i woke up thi mornin ' feelin ' round for my s...
# 2       want to cross but i do n't think i can it 's t...
# 3       we live in everi moment but thi one whi do n't...
# 4       onc a true believ onc there wa a fire in your ...
#                               ...
# 4995    there are place i rememb all my life though so...
# 4996    littl grave i 'm griev , i will mend you sweet...
# 4997    everi day 's a new day that 's what i 've been...
# 4998    hey , let them do it again , yeah hey , you sa...
# 4999    there 's someth wrong , there 's a chill in th...
# Name: text, Length: 5000, dtype: object

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfid = TfidfVectorizer(analyzer= 'word', stop_words= 'english')

# %%
tfid.fit_transform(df['text'])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 268824 stored elements and shape (5000, 23892)>

# %%
matrix = tfid.fit_transform(df['text'])

# %%
similer = cosine_similarity(matrix)

# %%
similer[0]
# Out:
# array([1.        , 0.0229098 , 0.01404126, ..., 0.01014238, 0.0026304 ,
#        0.0061303 ])

# %%
def recommender(song_name):
    idx = df[df['song']==song_name].index[0]
    distance = sorted(list(enumerate(similer[idx])), reverse= True, key = lambda x:x[1])
    song= []
    for s_id in distance[1:21]:
        song.append(df.iloc[s_id[0]].song)
    return song

# %%
idx = df.index[df['song'] == 'In The Haughhh!'].tolist()
first_idx = idx[0] if idx else None

# %%
recommender("In My Life Medley")
# Out:
# ['In My Life',
#  'Life After Death',
#  'Night Of Your Life',
#  "You're All I Am",
#  'All My Life',
#  "Today's The First Day",
#  'Cold And Empty',
#  'If You Work Away',
#  'What A Song',
#  'Be Still',
#  'A Song For You',
#  'Live Life',
#  'In Real Life',
#  'All My Life',
#  'It Might Be You',
#  'Make It Matter',
#  "I've Waited All My Life For You",
#  'I Love You Team Breezy',
#  'In Another Lifetime',
#  'If I Could Live Your Life']

# %%
import pickle

# %%
pickle.dump(similer, open("similarity", "wb"))

# %%
pickle.dump(df, open("df", "wb"))
